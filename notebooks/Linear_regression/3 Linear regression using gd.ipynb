# %%
import numpy as np 
import pandas as pd 
import matplotlib
from matplotlib import pyplot as plt 
from sklearn.linear_model import LinearRegression 
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook_connected"
np.random.seed(42)

# %%
# solving sum mathematical conmfussion related to algo writing 
X = pd.DataFrame({
    "x" : [1,3],
    "y" : [2,4],
    "z" : [5,6]
})
w = [2,3,4]
y = [30,40]

# don't need to transpose manually , it managed by self with in np.dot() dot product via numpy 
np.dot(X,w), X.values @ w,  X @ w,X.dot(w)
# Out:
# (array([28, 42]),
#  array([28, 42]),
#  0    28
#  1    42
#  dtype: int64,
#  0    28
#  1    42
#  dtype: int64)

# %%
class LinearRegressionGD:

    def __init__(self, lr=0.01, epoches=50):
        self.lr = lr
        self.epoches = epoches
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X, y):
        X = np.insert(X, 0, 1, axis=1)
        weights = np.zeros(X.shape[1])

        for i in range(self.epoches):
            y_pred = X @ weights
            gradient = (X.T @ (y - y_pred)) / X.shape[0]
            weights = weights + self.lr * gradient

        self.intercept_ = weights[0]
        self.coef_ = weights[1:]

    def predict(self, X):
        return np.dot(X,self.coef_) + self.intercept_

# %%
my_lr = LinearRegressionGD()
sk_lr = LinearRegression()
my_lr.fit(X,y) , sk_lr.fit(X,y)
my_lr.predict(X), sk_lr.predict(X)
# Out:
# (array([29.07391475, 40.64536788]), array([30., 40.]))

# %%
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
my_lr = LinearRegressionGD(epoches = 100 , lr= 0.05)

# %%
my_lr.fit(X,y)
y_pred_my_lr = my_lr.predict(X)

# %%
df = pd.DataFrame({'x':X[:,0],'y':X[:,1],'z':y})
fig = px.scatter_3d(df, x='x', y='y', z='z')
f1_range = np.linspace(df['x'].min(), df['x'].max(), 30)
f2_range = np.linspace(df['y'].min(), df['y'].max(), 30)

F1, F2 = np.meshgrid(f1_range, f2_range)

# Flatten grid for prediction
grid = np.c_[F1.ravel(), F2.ravel()]

# ---------------------------
# 3) Predict Z values using your model

Z_pred = my_lr.predict(grid)
Z_pred = Z_pred.reshape(F1.shape)

# ---------------------------
# 4) Add prediction plane to scatter plot
# ---------------------------
fig.add_trace(
    go.Surface(
        x=F1,
        y=F2,
        z=Z_pred,
        colorscale="Viridis",
        opacity=0.5,
        showscale=False
    )
)

fig.update_layout(
    scene=dict(
        xaxis_title="X",
        yaxis_title="Y",
        zaxis_title="Prediction"
    )
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="f4114f28-8108-4cef-8f0f-1f1548c051cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f4114f28-8108-4cef-8f0f-1f1548c051cf")) {                    Plotly.newPlot(                        "f4114f28-8108-4cef-8f0f-1f1548c051cf",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":{"dtype":"f8","bdata":"aYiBQZQP87\u002fooSJ8iM2tP0uHKYeIx+I\u002fLe0xdoZJ3j++nUiqhKHnP5T5Effmduy\u002f7XIjckmz\u002fr8cYhNzs5Pcv7DVSic2AOo\u002fXG9XkwBJ8j8wbjxNjLPxv6Fsmod3BeQ\u002f0js9oW44478apYzLTBjZv0CmV9+8+M2\u002fQ\u002fyxI+8Y67+QBsdh+UrtPzhYbbDKvdQ\u002fOiugAxPauD\u002f6IytdQW+yv3Abwa6iqN2\u002frPfNLTL\u002f8L8IdECodET5P8TCNmO8oIo\u002fj+MlX+xr7b\u002fBbA5bNR7Mvw06yBDZ8XQ\u002f\u002f1qwA0BA9b9fMbI2IJu9v3wwqSgqyt8\u002fOIpGXqJ9tz+mMWnmyirGPxLk7nBDmfu\u002fAdZ0NMPC5b8EJo3KW6X2vxsCfkTRLf4\u002faF4kUN255D9NOahTWKnl
gNzC\u002fpP\u002fyNN7izGe2\u002fTLhQDejCBUDe1B7Ji+7zv8MwUA\u002fPWv+\u002fzxHyveey8r9yFE0BSXjqP2JDLPvT4N4\u002fRsyHS2Ls8L8AaBhqqjfvPw+CbpAX2eY\u002fNQYxP2xlvD9gVYk14w6zv2InDcHEy\u002fa\u002fMdc5yccI+T8a5Ehh+232vyemqLj2COe\u002fTBpOp0Otwz\u002fcO7eQB0PqvyBgEDvMm\u002fg\u002fFIEdLCG10D+zLI5qHB\u002fiv2LC1\u002f746fA\u002fFIwxZrEE6T8="},"z":{"dtype":"f8","bdata":"uPIruqDHNsAqYV3LdORawNnnbw\u002fvI2lAoKwz5s6u9z\u002f0mBKtGvNbQE2fxrHdQ1vAFGBoXkC2acDM1Ebca9BDQCz6cIs7b3FA4YMewcQfY0BcMkleQkhrwKBh4HjiCEPA+KmJ2aI8XMCnaz+2OaRewHfiFqphsVrAxg8cJfqwYcAIN4tJVfxVQLGuLRdF\u002fUrAYhTzBXLNR0Aa1WTe2+1YQGAM30cZvEjARA0b5OkHVMCn7rfrcJBiQNmLhLoamlhAZ0W85XxXREADm8smATdAQMwq2rfZ9jxAzhApy\u002fppaMCO8ND7lUVcwPT9+ENo31VAYoCLMGcdYsAuXBalA85SQAAy+0Kbwda\u002fzQPI6w ...

# %%
sk_lr = LinearRegression()
sk_lr.fit(X,y)
y_pred_sk_lr = sk_lr.predict(X)
from sklearn.metrics import r2_score
r2_score(y,y_pred_sk_lr) ,r2_score(y,y_pred_my_lr)
# Out:
# (0.7819072511229945, 0.7816885200498906)

# %%
X_ = pd.DataFrame({
    "x" : [1,3],
    "y" : [2,4],
    "z" : [5,6]
})
w = [2,3,4]
y_ = [30,40]

# don't need to transpose manually , it managed by self with in np.dot() dot product via numpy 
print(np.dot(X_,w), X_.values @ w )
print(X_ @ w)
print(X_.dot(w))
X_
# Out:
# [28 42] [28 42]
# 0    28
# 1    42
# dtype: int64
# 0    28
# 1    42
# dtype: int64
#    x  y  z
# 0  1  2  5
# 1  3  4  6

# %%
X_.insert(0 , "new"  , np.ones(X_.shape[0]))

# %%
import numpy as np

class LinearRegressionSGD:

    def __init__(self, lr=0.01, epoches=10):
        self.lr = lr
        self.epoches = epoches
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X, y):
        # add bias term
        X = np.insert(X, 0, 1, axis=1)
        weights = np.zeros(X.shape[1])

        n = X.shape[0]

        for _ in range(self.epoches):
            for _ in range(n):
                r = np.random.randint(0, n)
                y_pred = X[r] @ weights
                error = y[r] - y_pred
                gradient = error * X[r]          # <-- vector gradient
                weights = weights + self.lr * gradient

        self.intercept_ = weights[0]
        self.coef_ = weights[1:]

    def predict(self, X):
        return X @ self.coef_ + self.intercept_

# %%
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
sgd_lr = LinearRegressionSGD(epoches = 100)
sgd_lr.fit(X,y)
pred = sgd_lr.predict(X)
from sklearn.metrics import r2_score
r2_score(y,pred)
# Out:
# 0.7388099735951574

# %%
# look result is so much bad so we first we need to normalize the data to get best results 
from sklearn.preprocessing  import StandardScaler 
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
sgd_lr = LinearRegressionSGD(epoches = 50)
sgd_lr.fit(X,y)
pred = sgd_lr.predict(X)
from sklearn.metrics import r2_score
r2_score(y,pred)
# Out:
# 0.7366580853123803
